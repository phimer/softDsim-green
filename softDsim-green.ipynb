# %%
# Import seaborn
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # differences between the 5 test runs

# %%
co2 = {'no compression': [0.355, 0.354,0.355,0.355,0.355],
    'brotli': [0.264,0.264,0.264,0.264,0.264],
    'gzip': [0.265,0.265,0.266,0.265,0.265]}

df = pd.DataFrame(data=co2)
df.index = np.arange(1, len(df) + 1)
df
# Out:
#    no compression  brotli   gzip
# 1           0.355   0.264  0.265
# 2           0.354   0.264  0.265
# 3           0.355   0.264  0.266
# 4           0.355   0.264  0.265
# 5           0.355   0.264  0.265

# %%
mhw = {'no compression': [0.804, 0.801,0.803,0.803,0.803],
    'brotli': [0.597,0.597,0.597,0.597,0.598],
    'gzip': [0.599,0.599,0.601,0.600,0.601]}

df2 = pd.DataFrame(data=mhw)
df2.index = np.arange(1, len(df) + 1)
df2
# Out:
#    no compression  brotli   gzip
# 1           0.804   0.597  0.599
# 2           0.801   0.597  0.599
# 3           0.803   0.597  0.601
# 4           0.803   0.597  0.600
# 5           0.803   0.598  0.601

# %%
# Apply the default theme
sns.set_theme(style="white")

fig, axes = plt.subplots(1,2, figsize=(12, 4))

# plot 1
ax1 = sns.lineplot(
    data=df,
    markers=True,
    ax=axes[1]
)
ax1.set(xlabel='Test-Run', ylabel='CO2 emissions (grams) per execution ')
ax1.set(ylim=(0.25, 0.4))
ax1.set(xticks=[1,2,3,4,5])
ax1.set(title='Runs of Experiment 2')

# plot 2
ax2 = sns.lineplot(
    data=df2,
    markers=True,
    ax=axes[0]
)
ax2.set(xlabel='Test-Run', ylabel='Electricity usage (Wh) per execution ')
ax2.set(ylim=(0.5, 1))
ax2.set(xticks=[1,2,3,4,5])
ax2.set(title='Runs of Experiment 2')

plt.show()

# %% [markdown]
# # file sizes with different compression algorithms

# %%
a = 'file-size at client'
b = 'size transferred over network'

file_sizes_10 = {'compression': ['none', 'brotli', 'gzip','none', 'brotli', 'gzip'],
                 'size': [186.91, 186.91, 186.91, 187.34, 1.19, 2.79],
                 'c': [a,a,a,b,b,b]}         


df = pd.DataFrame(data=file_sizes_10, index=[0,1,2,3,4,5])
# df.index = np.arange(1, len(df) + 1)

plt.figure(figsize=(20,12), dpi=80)
ax = sns.barplot(data=df,x='compression', y='size', hue='c')
plt.legend(loc='upper right')

plt.ylabel('Filesize in Bytes',fontsize=18)
plt.xlabel('Compression Type',fontsize=18)
plt.title(f'Title?', fontsize=20)
ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])
# plt.ylim(0, 200)
# plt.xlim(90, 180)
# plt.legend(title='At Bat')

plt.show()

# %%
df = sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]
